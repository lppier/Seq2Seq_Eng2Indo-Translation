# %% [markdown]
# ## English to Indonesian translation using attention

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import os

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable

# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable

# Loss function: https://pytorch.org/docs/stable/nn.html#torch.nn.NLLLoss

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_cuda = torch.cuda.is_available()

# %%
import pandas as pd
from gensim.corpora.dictionary import Dictionary
from nltk import word_tokenize

# %%
fp = open('./corpus/eng-indo.txt', 'r')
text = fp.read()
text = text.splitlines()
fp.close()

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s


text_dict = {"English": [], "Indonesian": []}
for l in text:
    split_text = l.split("\t")
    text_dict["English"].append(normalizeString(split_text[0]))
    text_dict["Indonesian"].append(normalizeString(split_text[1]))
    
df = pd.DataFrame.from_dict(text_dict)
print(df.shape)
df.head()
# Out:
# (6752, 2)
#   English Indonesian
# 0   run !     lari !
# 1   who ?    siapa ?
# 2   wow !      wow !
# 3  help !   tolong !
# 4  jump !   lompat !

# %%
MAX_LENGTH = 15
MIN_LENGTH = 4

# %%
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re ",
    "tom is", "tom s",
    "what s", "what a",
   "are you", "do you",
   "what is", "tom was",
   "don t", "it s", "where s",
   "where did", "where is",
)

def should_keep_row(row):
    """ Should the current row be kept as training set"""
    # indo_num_words = len(word_tokenize(row["Indonesian"]))
    eng_num_words = len(word_tokenize(row["English"]))
    max_words_required = MAX_LENGTH - 2
    min_words_required = MIN_LENGTH

    return eng_num_words <= max_words_required

df["keep_row"] = df.apply(should_keep_row, axis=1)
print(df.shape)
df.head()

print("Current shape: " + str(df.shape))
df = df[df["keep_row"]]
print("New shape: " + str(df.shape))
df.head()
df = df.reset_index().drop(columns=["keep_row"])
df.head()
# Out:
# (6752, 3)
# Current shape: (6752, 3)
# New shape: (6609, 3)
#    index     English            Indonesian
# 0     34   i m sad .          saya sedih .
# 1     35   it s me !             ini aku !
# 2     53  i get it .        aku mengerti .
# 3     54  i got it .        aku mengerti .
# 4     57  i m okay .  aku baik baik saja .

# %%
# Use a unique string to indicate START and END of a sentence.
# Assign a unique index to them.
START, START_IDX = '<s>',  0
END, END_IDX = '</s>', 1
UNK, UNK_IDX = 'UNK', 2

SOS_token = START_IDX
EOS_token = END_IDX

# We use this idiom to tokenize our sentences in the dataframe column:
# >>> DataFrame['column'].apply(str.lower).apply(word_tokenize)

# Also we added the START and the END symbol to the sentences. 
english_sents = [START] + df['English'].apply(str.lower).apply(word_tokenize) + [END]
indo_sents = [START] + df['Indonesian'].apply(str.lower).apply(word_tokenize) + [END]

# We're sort of getting into the data into the shape we want. 
# But now it's still too humanly readable and redundant.
## Cut-away: Computers like it to be simpler, more concise. -_-|||
print('First English sentence:', english_sents[0])
print('First Indo sentence:', indo_sents[0])

english_vocab = Dictionary([['<s>'], ['</s>'],['UNK']])
english_vocab.add_documents(english_sents)

indo_vocab = Dictionary([['<s>'], ['</s>'], ['UNK']])
indo_vocab.add_documents(indo_sents)

# First ten words in the vocabulary.
print('First 10 Indonesian words in Dictionary:\n', sorted(indo_vocab.items())[:10])
print()
print('First 10 English words in Dictionary:\n', sorted(english_vocab.items())[:10])

english_vocab = Dictionary([['<s>'], ['</s>'],['UNK']])
english_vocab.add_documents(english_sents)

indo_vocab = Dictionary([['<s>'], ['</s>'], ['UNK']])
indo_vocab.add_documents(indo_sents)

# First ten words in the vocabulary.
print('First 10 Indonesian words in Dictionary:\n', sorted(indo_vocab.items())[:10])
print()
print('First 10 English words in Dictionary:\n', sorted(english_vocab.items())[:10])
# Out:
# First English sentence: ['<s>', 'i', 'm', 'sad', '.', '</s>']
# First Indo sentence: ['<s>', 'saya', 'sedih', '.', '</s>']
# First 10 Indonesian words in Dictionary:
#  [(0, '<s>'), (1, '</s>'), (2, 'UNK'), (3, '.'), (4, 'saya'), (5, 'sedih'), (6, '!'), (7, 'aku'), (8, 'ini'), (9, 'mengerti')]
#
# First 10 English words in Dictionary:
#  [(0, '<s>'), (1, '</s>'), (2, 'UNK'), (3, '.'), (4, 'i'), (5, 'm'), (6, 'sad'), (7, '!'), (8, 'it'), (9, 'me')]
# First 10 Indonesian words in Dictionary:
#  [(0, '<s>'), (1, '</s>'), (2, 'UNK'), (3, '.'), (4, 'saya'), (5, 'sedih'), (6, '!'), (7, 'aku'), (8, 'ini'), (9, 'mengerti')]
#
# First 10 English words in Dictionary:
#  [(0, '<s>'), (1, '</s>'), (2, 'UNK'), (3, '.'), (4, 'i'), (5, 'm'), (6, 'sad'), (7, '!'), (8, 'it'), (9, 'me')]

# %%
import pickle
# Lets save our dictionaries.
#with open('./vocabs/simple_indo_vocab.Dictionary.pkl', 'wb') as fout:
#    pickle.dump(indo_vocab, fout)
    
#with open('./vocabs/simple_english_vocab.Dictionary.pkl', 'wb') as fout:
#    pickle.dump(english_vocab, fout)

# %%
# Vectorizes a sentence with a given vocab
def vectorize_sent(sent, vocab):
    return vocab.doc2idx([START] + word_tokenize(sent.lower()) + [END], unknown_word_index=2)

# Creates a PyTorch variable from a sentence against a given vocab
def variable_from_sent(sent, vocab):
    vsent = vectorize_sent(sent, vocab)
    #print(vsent)
    result = Variable(torch.LongTensor(vsent).view(-1, 1))
    #print(result)
    return result.cuda() if use_cuda else result

# Test
new_kopi = "Is it love?"
variable_from_sent(new_kopi, english_vocab)
# Out:
# tensor([[ 0],
#         [32],
#         [ 8],
#         [45],
#         [15],
#         [ 1]], device='cuda:0')

# %% [markdown]
# ## Split into train and validation

# %%
from sklearn.model_selection import train_test_split
df_train, df_val = train_test_split(df, test_size=0.15)
print(df_train.shape)
print(df_val.shape)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_train.head()

indo_tensors = df_train['Indonesian'].apply(lambda s: variable_from_sent(s, indo_vocab))
print(df_train.iloc[0]['Indonesian'])
df_train

english_tensors = df_train['English'].apply(lambda s: variable_from_sent(s, english_vocab))
#print(df_train.iloc[0]['English'])
#print(english_tensors[0])
# Now, each item in `sent_pairs` is our data point. 
#print("############################")
sent_pairs = list(zip(english_tensors.values, indo_tensors.values))
#print(sent_pairs[:5])
#print("############################")
pairs = list(zip(df_train['English'], df_train['Indonesian']))
print(pairs[0])
# Out:
# (5617, 3)
# (992, 3)
# perutku sakit .
# ('my stomach hurts .', 'perutku sakit .')

# %%
def get_validation_pairs(df_val_in): #MOD Anurag
    indo_val_tensors = df_val_in['Indonesian'].apply(lambda s: variable_from_sent(s, indo_vocab))
    english_val_tensors = df_val_in['English'].apply(lambda s: variable_from_sent(s, english_vocab))
    val_sent_tensor_pairs = list(zip(english_val_tensors.values, indo_val_tensors.values))
    val_sent_pairs = list(zip(df_val_in['English'], df_val_in['Indonesian']))
    return val_sent_pairs, val_sent_tensor_pairs


val_sent_pairs, val_sent_tensor_pairs = get_validation_pairs(df_val) #MOD Anurag
print(val_sent_pairs[0])
# Out:
# ('tom poured cold water over his head .', 'tom menuangkan air dingin ke kepalanya .')

# %%
print(val_sent_pairs[-1])
# Out:
# ('have you ever been to hawaii ?', 'pernahkah kau ke hawaii ?')

# %%
print(val_sent_pairs[154])
# Out:
# ('don t be a wet blanket .', 'jangan suka mengganggu kesenangan orang lain .')

# %%
print(val_sent_pairs[154][0])

for w in val_sent_pairs[154][0].split(' '):
    print(english_vocab.doc2idx([w]))
# Out:
# don t be a wet blanket .
# [38]
# [40]
# [104]
# [72]
# [935]
# [1112]
# [3]

# %% [markdown]
# ## Define model

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# ## Get training and validation loss <- Bug here for evaluation loss

# %%
teacher_forcing_ratio = 0.5


def get_train_loss(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    
    #print("Train")
    #print("Input tensor shape: {0}".format(input_tensor.shape))
    #print("Target tensor shape: {0}".format(target_tensor.shape))

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

def get_validation_loss(input_tensor, target_tensor, encoder, decoder, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    
    #print("Validation")
    #print("Input tensor shape: {0}".format(input_tensor.shape))
    #print("Target tensor shape: {0}".format(target_tensor.shape))

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    total_loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden
    
    with torch.no_grad():
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss = criterion(decoder_output, target_tensor[di])
            total_loss += float(loss.item())
            if decoder_input.item() == EOS_token:
                break

    return total_loss / target_length

# %% [markdown]
# ## Utilities

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))


SAVE_PATH = 'results'

if not os.path.exists(SAVE_PATH):
  os.makedirs(SAVE_PATH)

import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points, filename): # pier mod
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.savefig(filename)

# %% [markdown]
# ## Training loop and get evaluation result

# %%
def trainIters(encoder, decoder, n_iters, batch_size=1, print_every=1000, save_every=1000, plot_every=100,
               learning_rate=0.0001):
    start = time.time()
    plot_losses = []
    val_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    # training_pairs = [sent_pairs[i] for i in range(n_iters)]
    training_pairs = [random.sample(sent_pairs, batch_size) for i in range(n_iters)]

    # training_pairs = [tensorsFromPair(random.choice(pairs)) for i in range(n_iters)]
    criterion = nn.NLLLoss()
    MAX_PATIENCE = 10
    patience = MAX_PATIENCE  # mod Pier
    prev_val_loss =lowest_so_far = 999
    stopping_criteria_on = False

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        # print("################################")
        # print(training_pair)
        input_tensor = training_pair[0][0]
        target_tensor = training_pair[0][1]
        # print("printing tensors for training...")
        # print(input_tensor)
        # print(target_tensor)

        loss = get_train_loss(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer,
                              criterion)
        print_loss_total += loss
        plot_loss_total += loss

        stopping_delta = 0.001  # if improvement is not more than this amount after n tries, exit the loop


        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('Training loss: %s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                                        iter, iter / n_iters * 100, print_loss_avg))

            total_val_loss = 0
            total_val_pairs = len(val_sent_tensor_pairs)

            for itr in range(0, len(val_sent_tensor_pairs)):
                val_input_tensor = val_sent_tensor_pairs[itr][0]
                val_target_tensor = val_sent_tensor_pairs[itr][1]
                # print("Validation record: {0}".format(itr))
                # print(val_sent_pairs[itr])
                val_loss = get_validation_loss(val_input_tensor, val_target_tensor, encoder, decoder, criterion)
                total_val_loss += val_loss

            avg_val_loss = total_val_loss / total_val_pairs
            val_losses.append(avg_val_loss)
            print('Validation loss: %s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                                          iter, iter / n_iters * 100, avg_val_loss))
            
            if  stopping_criteria_on:
                # mod Pier
                if (prev_val_loss - avg_val_loss) > stopping_delta and avg_val_loss < lowest_so_far:
                    print(f"Improvement in validation loss, saving model. Prev {prev_val_loss} Curr {avg_val_loss}")
                    lowest_so_far = avg_val_loss
                    encoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'encoder', iter)
                    print('save encoder weights to ', encoder_save_path)
                    torch.save(encoder.state_dict(), encoder_save_path)
                    decoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'decoder', iter)
                    print('save decoder weights to ', decoder_save_path)
                    torch.save(decoder.state_dict(), decoder_save_path)
                    patience = MAX_PATIENCE # reset to max
                else:
                    print(f"No improvement in validation loss, losing patience {patience}")
                    patience -= 1

                if patience == 0:  # break out of training
                    break

                prev_val_loss = avg_val_loss
                # end mod Pier

            print("##########################################################")

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

        # # save trained encoder and decoder
        # if iter % save_every == 0:
        #     encoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'encoder', iter)
        #     print('save encoder weights to ', encoder_save_path)
        #     torch.save(encoder.state_dict(), encoder_save_path)
        #     decoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'decoder', iter)
        #     print('save decoder weights to ', decoder_save_path)
        #     torch.save(decoder.state_dict(), decoder_save_path)

    showPlot(plot_losses, 'train_plot.png')
    showPlot(val_losses, 'validation_plot.png')

    return plot_losses, val_losses

# %%
# def trainIters(encoder, decoder, n_iters, batch_size=1, print_every=1000, save_every=1000, plot_every=100,
#                learning_rate=0.0001):
#     start = time.time()
#     plot_losses = []
#     val_losses = []
#     print_loss_total = 0  # Reset every print_every
#     plot_loss_total = 0  # Reset every plot_every
# 
#     encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
#     decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
#     # training_pairs = [sent_pairs[i] for i in range(n_iters)]
#     training_pairs = [random.sample(sent_pairs, batch_size) for i in range(n_iters)]
# 
#     # training_pairs = [tensorsFromPair(random.choice(pairs)) for i in range(n_iters)]
#     criterion = nn.NLLLoss()
# 
#     patience = 10  # mod Pier
# 
#     for iter in range(1, n_iters + 1):
#         training_pair = training_pairs[iter - 1]
#         # print("################################")
#         # print(training_pair)
#         input_tensor = training_pair[0][0]
#         target_tensor = training_pair[0][1]
#         # print("printing tensors for training...")
#         # print(input_tensor)
#         # print(target_tensor)
# 
#         loss = get_train_loss(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer,
#                               criterion)
#         print_loss_total += loss
#         plot_loss_total += loss
# 
#         stopping_delta = 0.01  # if improvement is not more than this amount after n tries, exit the loop
#         prev_val_loss = 999
# 
#         if iter % print_every == 0:
#             print_loss_avg = print_loss_total / print_every
#             print_loss_total = 0
#             print('Training loss: %s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
#                                                         iter, iter / n_iters * 100, print_loss_avg))
# 
#             total_val_loss = 0
#             total_val_pairs = len(val_sent_tensor_pairs)
# 
#             for itr in range(0, len(val_sent_tensor_pairs)):
#                 val_input_tensor = val_sent_tensor_pairs[itr][0]
#                 val_target_tensor = val_sent_tensor_pairs[itr][1]
#                 # print("Validation record: {0}".format(itr))
#                 # print(val_sent_pairs[itr])
#                 val_loss = get_validation_loss(val_input_tensor, val_target_tensor, encoder, decoder, criterion)
#                 total_val_loss += val_loss
# 
#             avg_val_loss = total_val_loss / total_val_pairs
#             val_losses.append(avg_val_loss)
#             print('Validation loss: %s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
#                                                           iter, iter / n_iters * 100, avg_val_loss))
# 
#             # mod P_ier
#             if abs(avg_val_loss - prev_val_loss) > stopping_delta:
#                 print(f"No improvement in validation loss, losing patience, saving model : {patience}")
#                 encoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'encoder', iter)
#                 print('save encoder weights to ', encoder_save_path)
#                 torch.save(encoder.state_dict(), encoder_save_path)
#                 decoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'decoder', iter)
#                 print('save decoder weights to ', decoder_save_path)
#                 torch.save(decoder.state_dict(), decoder_save_path)
# 
#                 patience -= 1
# 
#             if patience == 0:  # break out of training
#                 break
# 
#             prev_val_loss = avg_val_loss
#             # end mod Pier
# 
#             print("##########################################################")
# 
#         if iter % plot_every == 0:
#             plot_loss_avg = plot_loss_total / plot_every
#             plot_losses.append(plot_loss_avg)
#             plot_loss_total = 0
# 
#         # # save trained encoder and decoder
#         # if iter % save_every == 0:
#         #     encoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'encoder', iter)
#         #     print('save encoder weights to ', encoder_save_path)
#         #     torch.save(encoder.state_dict(), encoder_save_path)
#         #     decoder_save_path = '%s/%s-%d.pth' % (SAVE_PATH, 'decoder', iter)
#         #     print('save decoder weights to ', decoder_save_path)
#         #     torch.save(decoder.state_dict(), decoder_save_path)
# 
#     showPlot(plot_losses, 'train_plot.png')
#     showPlot(val_losses, 'validation_plot.png')
# 
#     return plot_losses, val_losses

def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        # input_tensor = tensorFromSentence(input_lang, sentence)
        input_tensor = variable_from_sent(sentence, english_vocab)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('</s>')
                break
            else:
                decoded_words.append(indo_vocab.id2token[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# ## Perform training

# %%
hidden_size = 512
encoder1 = EncoderRNN(len(english_vocab), hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, len(indo_vocab), dropout_p=0.1).to(device)

plot_losses, val_losses = trainIters(encoder1, attn_decoder1, 100000, print_every=100)

showPlot(plot_losses, 'train_plot.png')
showPlot(val_losses, 'validation_plot.png')

evaluateRandomly(encoder1, attn_decoder1)

output_words, attentions = evaluate(
    encoder1, attn_decoder1, "do you love me?")
# Out:
# Training loss: 0m 2s (- 33m 29s) (100 0%) 8.3043
# Validation loss: 0m 8s (- 135m 57s) (100 0%) 8.2576
# ##########################################################
# Training loss: 0m 9s (- 81m 52s) (200 0%) 8.2217
# Validation loss: 0m 16s (- 133m 37s) (200 0%) 8.1706
# ##########################################################
# Training loss: 0m 17s (- 98m 50s) (300 0%) 8.1346
# Validation loss: 0m 24s (- 133m 8s) (300 0%) 8.0448
# ##########################################################
# Training loss: 0m 25s (- 106m 55s) (400 0%) 8.0040
# Validation loss: 0m 32s (- 134m 10s) (400 0%) 7.8142
# ##########################################################
# Training loss: 0m 34s (- 113m 38s) (500 0%) 7.7798
# Validation loss: 0m 40s (- 135m 11s) (500 0%) 7.4110
# ##########################################################
# Training loss: 0m 42s (- 117m 4s) (600 0%) 7.5320
# Validation loss: 0m 48s (- 133m 49s) (600 0%) 6.8716
# ##########################################################
# Training loss: 0m 50s (- 118m 42s) (700 0%) 7.3591
# Validation loss: 0m 56s (- 132m 57s) (700 0%) 7.0682
# ##########################################################
# Training loss: 0m 58s (- 119m 52s) (800 0%) 7.2490
# Validation loss: 1m 4s (- 132m 39s) (800 0%) 6.7394
# ##########################################################
# Training loss: 1m 5s (- 121m 0s) (900 0%) 7.0257
# Validation loss: 1m 12s (- 132m 30s) (900 0%) 6.3605
# ##########################################################
# Training loss: 1m 13s (- 121m 56s) (1000 1%) 6.6204
# Validation loss: 1m 19s (- 131m 35s) (1000 1%) 5.9204
# ##########################################################
# Training loss: 1m 21s (- 122m 2s) (1100 1%) 6.3749
# Validation loss: 1m 26s (- 130m 19s) (1100 1%) 5.4838
# ##########################################################
# Training loss: 1m 28s (- 121m 26s) (1200 1%) 5.8725
# Validation loss: 1m 33s (- 127m 56s) (1200 1%) 4.8909
# ##########################################################
# Training loss: 1m 34s (- 119m 58s) (1300 1%) 5.8684
# Validation loss: 1m 39s (- 126m 4s) (1300 1%) 4.5562
# ##########################################################
# Training loss: 1m 41s (- 118m 50s) (1400 1%) 5.2791
# Validation loss: 1m 46s (- 124m 29s) (1400 1%) 4.1031
# ##########################################################
# Training loss: 1m 47s (- 118m 2s) (1500 1%) 5.2903
# Validation loss: 1m 52s (- 123m 4s) (1500 1%) 4.0655
# ##########################################################
# Training loss: 1m 54s (- 116m 56s) (1600 1%) 5.4046
# Validation loss: 1m 58s (- 121m 20s) (1600 1%) 3.5448
# ##########################################################
# Training loss: 1m 59s (- 115m 32s) (1700 1%) 4.4125
# Validation loss: 2m 3s (- 119m 27s) (1700 1%) 3.1183
# ##########################################################
# Training loss: 2m 5s (- 114m 14s) (1800 1%) 4.8586
# Validation loss: 2m 9s (- 118m 3s) (1800 1%) 3.0949
# ##########################################################
# Training loss: 2m 11s (- 113m 9s) (1900 1%) 4.8298
# Validation loss: 2m 15s (- 116m 43s) (1900 1%) 3.0678
# ##########################################################
# Training loss: 2m 17s (- 111m 57s) (2000 2%) 4.5181
# Validation loss: 2m 21s (- 115m 11s) (2000 2%) 3.0374
# ##########################################################
# Training loss: 2m 22s (- 110m 49s) (2100 2%) 4.4979
# Validation loss: 2m 26s (- 113m 56s) (2100 2%) 2.9813
# ##########################################################
# Training loss: 2m 28s (- 109m 50s) (2200 2%) 4.2916
# Validation loss: 2m 32s (- 112m 45s) (2200 2%) 2.8337
# ##########################################################
# Training loss: 2m 33s (- 108m 44s) (2300 2%) 4.0979
# Validation loss: 2m 37s (- 111m 25s) (2300 2%) 2.6438
# ##########################################################
# Training loss: 2m 38s (- 107m 39s) (2400 2%) 4.2167
# Validation loss: 2m 42s (- 109m 57s) (2400 2%) 1.9443
# ##########################################################
# Training loss: 2m 43s (- 106m 20s) (2500 2%) 3.6677
# Validation loss: 2m 46s (- 108m 32s) (2500 2%) 1.9296
# ##########################################################
# Training loss: 2m 48s (- 105m 5s) (2600 2%) 3.6968
# Validation loss: 2m 51s (- 107m 17s) (2600 2%) 1.9151
# ##########################################################
# Training loss: 2m 53s (- 104m 7s) (2700 2%) 3.6602
# Validation loss: 2m 56s (- 106m 12s) (2700 2%) 1.9005
# ##########################################################
# Training loss: 2m 58s (- 103m 6s) (2800 2%) 3.8522
# Validation loss: 3m 1s (- 105m 3s) (2800 2%) 1.8869
# ##########################################################
# Training loss: 3m 2s (- 102m 4s) (2900 2%) 3.5983
# Validation loss: 3m 6s (- 103m 54s) (2900 2%) 1.8825
# ##########################################################
# Training loss: 3m 7s (- 101m 5s) (3000 3%) 3.9618
# Validation loss: 3m 11s (- 103m 10s) (3000 3%) 2.9131
# ##########################################################
# Training loss: 3m 12s (- 100m 28s) (3100 3%) 4.2907
# Validation loss: 3m 17s (- 102m 44s) (3100 3%) 3.6275
# ##########################################################
# Training loss: 3m 18s (- 100m 10s) (3200 3%) 4.6464
# Validation loss: 3m 23s (- 102m 23s) (3200 3%) 3.6690
# ##########################################################
# Training loss: 3m 24s (- 99m 55s) (3300 3%) 4.5688
# Validation loss: 3m 28s (- 102m 3s) (3300 3%) 3.6428
# ##########################################################
# Training loss: 3m 30s (- 99m 38s) (3400 3%) 4.4464
# Validation loss: 3m 34s (- 101m 42s) (3400 3%) 3.6167
# ##########################################################
# Training loss: 3m 36s (- 99m 22s) (3500 3%) 4.3254
# Validation loss: 3m 40s (- 101m 20s) (3500 3%) 3.5975
# ##########################################################
# Training loss: 3m 42s (- 99m 5s) (3600 3%) 4.4090
# Validation loss: 3m 46s (- 101m 0s) (3600 3%) 3.5804
# ##########################################################
# Training loss: 3m 47s (- 98m 49s) (3700 3%) 4.5133
# Validation loss: 3m 52s (- 100m 41s) (3700 3%) 3.5639
# ##########################################################
# Training loss: 3m 53s (- 98m 35s) (3800 3%) 4.3298
# Validation loss: 3m 57s (- 100m 24s) (3800 3%) 3.5449
# ##########################################################
# Training loss: 3m 59s (- 98m 21s) (3900 3%) 4.4762
# Validation loss: 4m 3s (- 100m 6s) (3900 3%) 3.5304
# ##########################################################
# Training loss: 4m 5s (- 98m 5s) (4000 4%) 4.3205
# Validation loss: 4m 9s (- 99m 51s) (4000 4%) 3.5179
# ##########################################################
# Training loss: 4m 11s (- 97m 57s) (4100 4%) 4.2929
# Validation loss: 4m 15s (- 99m 43s) (4100 4%) 3.5058
# ##########################################################
# Training loss: 4m 17s (- 97m 51s) (4200 4%) 4.2670
# Validation loss: 4m 21s (- 99m 31s) (4200 4%) 3.4945
# ##########################################################
# Training loss: 4m 23s (- 97m 38s) (4300 4%) 4.2520
# Validation loss: 4m 27s (- 99m 15s) (4300 4%) 3.4860
# ##########################################################
# Training loss: 4m 29s (- 97m 25s) (4400 4%) 4.1478
# Validation loss: 4m 33s (- 98m 59s) (4400 4%) 3.4701
# ##########################################################
# Training loss: 4m 34s (- 97m 14s) (4500 4%) 4.2844
# Validation loss: 4m 39s (- 98m 45s) (4500 4%) 3.4582
# ##########################################################
# Training loss: 4m 40s (- 97m 1s) (4600 4%) 4.3932
# Validation loss: 4m 45s (- 98m 32s) (4600 4%) 3.4465
# ##########################################################
# Training loss: 4m 46s (- 96m 51s) (4700 4%) 4.2763
# Validation loss: 4m 50s (- 98m 18s) (4700 4%) 3.4383
# ##########################################################
# Training loss: 4m 52s (- 96m 39s) (4800 4%) 4.0793
# Validation loss: 4m 56s (- 98m 4s) (4800 4%) 3.4278
# ##########################################################
# Training loss: 4m 58s (- 96m 27s) (4900 4%) 4.3454
# Validation loss: 5m 2s (- 97m 52s) (4900 4%) 3.4223
# ##########################################################
# Training loss: 5m 4s (- 96m 17s) (5000 5%) 4.1354
# Validation loss: 5m 8s (- 97m 38s) (5000 5%) 3.4098
# ##########################################################
# Training loss: 5m 9s (- 96m 6s) (5100 5%) 4.2186
# Validation loss: 5m 14s (- 97m 25s) (5100 5%) 3.3933
# ##########################################################
# Training loss: 5m 15s (- 95m 54s) (5200 5%) 4.3721
# Validation loss: 5m 20s (- 97m 13s) (5200 5%) 3.3898
# ##########################################################
# Training loss: 5m 21s (- 95m 44s) (5300 5%) 4.1696
# Validation loss: 5m 25s (- 97m 1s) (5300 5%) 3.3832
# ##########################################################
# Training loss: 5m 27s (- 95m 33s) (5400 5%) 4.1208
# Validation loss: 5m 31s (- 96m 50s) (5400 5%) 3.3749
# ##########################################################
# Training loss: 5m 33s (- 95m 23s) (5500 5%) 3.9210
# Validation loss: 5m 37s (- 96m 38s) (5500 5%) 3.3645
# ##########################################################
# Training loss: 5m 38s (- 95m 13s) (5600 5%) 4.3118
# Validation loss: 5m 43s (- 96m 26s) (5600 5%) 3.3569
# ##########################################################
# Training loss: 5m 44s (- 95m 3s) (5700 5%) 4.2139
# Validation loss: 5m 49s (- 96m 15s) (5700 5%) 3.3557
# ##########################################################
# Training loss: 5m 50s (- 94m 54s) (5800 5%) 4.1208
# Validation loss: 5m 54s (- 96m 4s) (5800 5%) 3.2709
# ##########################################################
# Training loss: 5m 56s (- 94m 44s) (5900 5%) 3.9628
# Validation loss: 6m 0s (- 95m 48s) (5900 5%) 2.8904
# ##########################################################
# Training loss: 6m 1s (- 94m 30s) (6000 6%) 4.2208
# Validation loss: 6m 6s (- 95m 38s) (6000 6%) 3.3515
# ##########################################################
# Training loss: 6m 7s (- 94m 21s) (6100 6%) 4.1386
# Validation loss: 6m 12s (- 95m 29s) (6100 6%) 3.3106
# ##########################################################
# Training loss: 6m 13s (- 94m 13s) (6200 6%) 4.2074
# Validation loss: 6m 17s (- 95m 17s) (6200 6%) 3.3273
# ##########################################################
# Training loss: 6m 19s (- 94m 3s) (6300 6%) 3.9854
# Validation loss: 6m 23s (- 95m 8s) (6300 6%) 3.3213
# ##########################################################
# Training loss: 6m 25s (- 93m 55s) (6400 6%) 4.0346
# Validation loss: 6m 29s (- 94m 58s) (6400 6%) 3.3130
# ##########################################################
# Training loss: 6m 31s (- 93m 45s) (6500 6%) 3.8922
# Validation loss: 6m 35s (- 94m 47s) (6500 6%) 3.3074
# ##########################################################
# Training loss: 6m 36s (- 93m 36s) (6600 6%) 4.0776
# Validation loss: 6m 41s (- 94m 38s) (6600 6%) 3.3015
# ##########################################################
# Training loss: 6m 42s (- 93m 29s) (6700 6%) 4.0567
# Validation loss: 6m 47s (- 94m 30s) (6700 6%) 3.2941
# ##########################################################
# Training loss: 6m 48s (- 93m 21s) (6800 6%) 3.8965
# Validation loss: 6m 53s (- 94m 21s) (6800 6%) 3.2924
# ##########################################################
# Training loss: 6m 54s (- 93m 13s) (6900 6%) 4.0506
# Validation loss: 6m 58s (- 94m 12s) (6900 6%) 3.2892
# ##########################################################
# Training loss: 7m 0s (- 93m 6s) (7000 7%) 3.9898
# Validation loss: 7m 4s (- 94m 4s) (7000 7%) 3.2841
# ##########################################################
# Training loss: 7m 6s (- 92m 59s) (7100 7%) 4.0147
# Validation loss: 7m 10s (- 93m 56s) (7100 7%) 3.2805
# ##########################################################
# Training loss: 7m 12s (- 92m 50s) (7200 7%) 3.9852
# Validation loss: 7m 16s (- 93m 47s) (7200 7%) 3.2783
# ##########################################################
# Training loss: 7m 18s (- 92m 42s) (7300 7%) 3.9011
# Validation loss: 7m 22s (- 93m 38s) (7300 7%) 3.2713
# ##########################################################
# Training loss: 7m 23s (- 92m 35s) (7400 7%) 3.8964
# Validation loss: 7m 28s (- 93m 30s) (7400 7%) 3.2670
# ##########################################################
# Training loss: 7m 29s (- 92m 28s) (7500 7%) 3.9434
# Validation loss: 7m 34s (- 93m 22s) (7500 7%) 3.2658
# ##########################################################
# Training loss: 7m 35s (- 92m 21s) (7600 7%) 3.9075
# Validation loss: 7m 40s (- 93m 14s) (7600 7%) 3.2606
# ##########################################################
# Training loss: 7m 41s (- 92m 14s) (7700 7%) 4.0944
# Validation loss: 7m 46s (- 93m 6s) (7700 7%) 3.2565
# ##########################################################
# Training loss: 7m 47s (- 92m 7s) (7800 7%) 4.0462
# Validation loss: 7m 51s (- 92m 59s) (7800 7%) 3.2516
# ##########################################################
# Training loss: 7m 53s (- 92m 0s) (7900 7%) 3.9445
# Validation loss: 7m 57s (- 92m 50s) (7900 7%) 3.2475
# ##########################################################
# Training loss: 7m 59s (- 91m 52s) (8000 8%) 4.0513
# Validation loss: 8m 3s (- 92m 42s) (8000 8%) 3.2433
# ##########################################################
# Training loss: 8m 5s (- 91m 44s) (8100 8%) 3.9707
# Validation loss: 8m 9s (- 92m 33s) (8100 8%) 3.2413
# ##########################################################
# Training loss: 8m 11s (- 91m 36s) (8200 8%) 3.9769
# Validation loss: 8m 15s (- 92m 25s) (8200 8%) 3.2403
# ##########################################################
# Training loss: 8m 16s (- 91m 29s) (8300 8%) 3.9801
# Validation loss: 8m 21s (- 92m 17s) (8300 8%) 3.2377
# ##########################################################
# Training loss: 8m 22s (- 91m 21s) (8400 8%) 3.8380
# Validation loss: 8m 26s (- 92m 8s) (8400 8%) 3.2332
# ##########################################################
# Training loss: 8m 28s (- 91m 14s) (8500 8%) 3.9931
# Validation loss: 8m 32s (- 91m 59s) (8500 8%) 3.2334
# ##########################################################
# Training loss: 8m 34s (- 91m 5s) (8600 8%) 4.0821
# Validation loss: 8m 38s (- 91m 52s) (8600 8%) 3.2276
# ##########################################################
# Training loss: 8m 40s (- 90m 59s) (8700 8%) 4.1636
# Validation loss: 8m 44s (- 91m 45s) (8700 8%) 3.2554
# ##########################################################
# Training loss: 8m 46s (- 90m 53s) (8800 8%) 4.1424
# Validation loss: 8m 50s (- 91m 40s) (8800 8%) 3.4307
# ##########################################################
# Training loss: 8m 52s (- 90m 47s) (8900 8%) 3.9689
# Validation loss: 8m 56s (- 91m 32s) (8900 8%) 3.2176
# ##########################################################
# Training loss: 8m 58s (- 90m 40s) (9000 9%) 3.9096
# Validation loss: 9m 2s (- 91m 24s) (9000 9%) 3.2142
# ##########################################################
# Training loss: 9m 3s (- 90m 33s) (9100 9%) 4.0456
# Validation loss: 9m 8s (- 91m 17s) (9100 9%) 3.2136
# ##########################################################
# Training loss: 9m 9s (- 90m 27s) (9200 9%) 3.9705
# Validation loss: 9m 14s (- 91m 13s) (9200 9%) 3.6140
# ##########################################################
# Training loss: 9m 16s (- 90m 23s) (9300 9%) 3.9349
# Validation loss: 9m 20s (- 91m 7s) (9300 9%) 3.3978
# ##########################################################
# Training loss: 9m 22s (- 90m 18s) (9400 9%) 4.0010
# Validation loss: 9m 26s (- 91m 1s) (9400 9%) 3.3912
# ##########################################################
# Training loss: 9m 28s (- 90m 12s) (9500 9%) 3.9216
# Validation loss: 9m 32s (- 90m 54s) (9500 9%) 3.2056
# ##########################################################
# Training loss: 9m 33s (- 90m 5s) (9600 9%) 4.0163
# Validation loss: 9m 38s (- 90m 45s) (9600 9%) 3.2034
# ##########################################################
# Training loss: 9m 39s (- 89m 57s) (9700 9%) 3.8992
# Validation loss: 9m 44s (- 90m 37s) (9700 9%) 3.2069
# ##########################################################
# Training loss: 9m 45s (- 89m 49s) (9800 9%) 3.8227
# Validation loss: 9m 49s (- 90m 29s) (9800 9%) 3.2023
# ##########################################################
# Training loss: 9m 51s (- 89m 42s) (9900 9%) 3.8850
# Validation loss: 9m 55s (- 90m 21s) (9900 9%) 3.1948
# ##########################################################
# Training loss: 9m 57s (- 89m 34s) (10000 10%) 3.9541
# Validation loss: 10m 1s (- 90m 13s) (10000 10%) 3.1927
# ##########################################################
# Training loss: 10m 3s (- 89m 27s) (10100 10%) 4.0119
# Validation loss: 10m 7s (- 90m 6s) (10100 10%) 3.1887
# ##########################################################
# Training loss: 10m 8s (- 89m 20s) (10200 10%) 3.8150
# Validation loss: 10m 13s (- 89m 59s) (10200 10%) 3.1882
# ##########################################################
# Training loss: 10m 14s (- 89m 13s) (10300 10%) 3.8147
# Validation loss: 10m 19s (- 89m 56s) (10300 10%) 3.7643
# ##########################################################
# Training loss: 10m 21s (- 89m 12s) (10400 10%) 3.9588
# Validation loss: 10m 25s (- 89m 49s) (10400 10%) 3.1819
# ##########################################################
# Training loss: 10m 27s (- 89m 5s) (10500 10%) 3.9873
# Validation loss: 10m 31s (- 89m 41s) (10500 10%) 3.1810
# ##########################################################
# Training loss: 10m 32s (- 88m 57s) (10600 10%) 3.8889
# Validation loss: 10m 37s (- 89m 34s) (10600 10%) 3.1776
# ##########################################################
# Training loss: 10m 38s (- 88m 50s) (10700 10%) 3.8959
# Validation loss: 10m 43s (- 89m 26s) (10700 10%) 3.1778
# ##########################################################
# Training loss: 10m 44s (- 88m 43s) (10800 10%) 3.8327
# Validation loss: 10m 48s (- 89m 19s) (10800 10%) 3.1738
# ##########################################################
# Training loss: 10m 50s (- 88m 36s) (10900 10%) 3.8127
# Validation loss: 10m 54s (- 89m 12s) (10900 10%) 3.1711
# ##########################################################
# Training loss: 10m 56s (- 88m 29s) (11000 11%) 3.7540
# Validation loss: 11m 0s (- 89m 5s) (11000 11%) 3.3280
# ##########################################################
# Training loss: 11m 2s (- 88m 23s) (11100 11%) 3.8809
# Validation loss: 11m 6s (- 88m 58s) (11100 11%) 3.1652
# ##########################################################
# Training loss: 11m 8s (- 88m 16s) (11200 11%) 3.9137
# Validation loss: 11m 12s (- 88m 51s) (11200 11%) 3.1611
# ##########################################################
# Training loss: 11m 13s (- 88m 10s) (11300 11%) 3.9236
# Validation loss: 11m 18s (- 88m 44s) (11300 11%) 3.2628
# ##########################################################
# Training loss: 11m 19s (- 88m 4s) (11400 11%) 4.0144
# Validation loss: 11m 24s (- 88m 38s) (11400 11%) 3.1625
# ##########################################################
# Training loss: 11m 25s (- 87m 57s) (11500 11%) 3.9818
# Validation loss: 11m 30s (- 88m 31s) (11500 11%) 3.1599
# ##########################################################
# Training loss: 11m 31s (- 87m 52s) (11600 11%) 3.9395
# Validation loss: 11m 36s (- 88m 25s) (11600 11%) 3.2957
# ##########################################################
# Training loss: 11m 37s (- 87m 45s) (11700 11%) 3.8635
# Validation loss: 11m 42s (- 88m 18s) (11700 11%) 3.2503
# ##########################################################
# Training loss: 11m 43s (- 87m 39s) (11800 11%) 3.9735
# Validation loss: 11m 47s (- 88m 11s) (11800 11%) 3.1516
# ##########################################################
# Training loss: 11m 49s (- 87m 32s) (11900 11%) 3.9331
# Validation loss: 11m 53s (- 88m 4s) (11900 11%) 3.1524
# ##########################################################
# Training loss: 11m 55s (- 87m 26s) (12000 12%) 4.0054
# Validation loss: 11m 59s (- 87m 58s) (12000 12%) 3.2047
# ##########################################################
# Training loss: 12m 1s (- 87m 21s) (12100 12%) 3.9456
# Validation loss: 12m 5s (- 87m 53s) (12100 12%) 3.3486
# ##########################################################
# Training loss: 12m 7s (- 87m 15s) (12200 12%) 3.9902
# Validation loss: 12m 11s (- 87m 46s) (12200 12%) 3.1597
# ##########################################################
# Training loss: 12m 13s (- 87m 8s) (12300 12%) 3.9124
# Validation loss: 12m 17s (- 87m 39s) (12300 12%) 3.1538
# ##########################################################
# Training loss: 12m 19s (- 87m 1s) (12400 12%) 3.8982
# Validation loss: 12m 23s (- 87m 32s) (12400 12%) 3.2148
# ##########################################################
# Training loss: 12m 24s (- 86m 54s) (12500 12%) 3.6349
# Validation loss: 12m 29s (- 87m 25s) (12500 12%) 3.1410
# ##########################################################
# Training loss: 12m 30s (- 86m 48s) (12600 12%) 3.8503
# Validation loss: 12m 35s (- 87m 19s) (12600 12%) 3.1773
# ##########################################################
# Training loss: 12m 36s (- 86m 42s) (12700 12%) 3.8937
# Validation loss: 12m 41s (- 87m 12s) (12700 12%) 3.2356
# ##########################################################
# Training loss: 12m 42s (- 86m 35s) (12800 12%) 3.7208
# Validation loss: 12m 46s (- 87m 4s) (12800 12%) 3.1353
# ##########################################################
# Training loss: 12m 48s (- 86m 27s) (12900 12%) 3.7467
# Validation loss: 12m 52s (- 86m 56s) (12900 12%) 3.1334
# ##########################################################
# Training loss: 12m 54s (- 86m 20s) (13000 13%) 3.7532
# Validation loss: 12m 58s (- 86m 49s) (13000 13%) 3.1313
# ##########################################################
# Training loss: 12m 59s (- 86m 13s) (13100 13%) 3.8191
# Validation loss: 13m 4s (- 86m 43s) (13100 13%) 3.2484
# ##########################################################
# Training loss: 13m 5s (- 86m 7s) (13200 13%) 3.8284
# Validation loss: 13m 10s (- 86m 37s) (13200 13%) 3.2774
# ##########################################################
# Training loss: 13m 11s (- 86m 2s) (13300 13%) 3.8785
# Validation loss: 13m 16s (- 86m 30s) (13300 13%) 3.1541
# ##########################################################
# Training loss: 13m 17s (- 85m 55s) (13400 13%) 3.8593
# Validation loss: 13m 22s (- 86m 25s) (13400 13%) 3.5497
# ##########################################################
# Training loss: 13m 23s (- 85m 51s) (13500 13%) 4.0572
# Validation loss: 13m 28s (- 86m 22s) (13500 13%) 3.6573
# ##########################################################
# Training loss: 13m 30s (- 85m 47s) (13600 13%) 3.9211
# Validation loss: 13m 34s (- 86m 16s) (13600 13%) 3.4766
# ##########################################################
# Training loss: 13m 36s (- 85m 42s) (13700 13%) 3.8842
# Validation loss: 13m 40s (- 86m 9s) (13700 13%) 3.1289
# ##########################################################
# Training loss: 13m 42s (- 85m 35s) (13800 13%) 3.7554
# Validation loss: 13m 46s (- 86m 2s) (13800 13%) 3.1226
# ##########################################################
# Training loss: 13m 47s (- 85m 28s) (13900 13%) 3.8836
# Validation loss: 13m 52s (- 85m 56s) (13900 13%) 3.2621
# ##########################################################
# Training loss: 13m 53s (- 85m 22s) (14000 14%) 3.8398
# Validation loss: 13m 58s (- 85m 50s) (14000 14%) 3.2976
# ##########################################################
# Training loss: 13m 59s (- 85m 16s) (14100 14%) 3.7891
# Validation loss: 14m 4s (- 85m 43s) (14100 14%) 3.1715
# ##########################################################
# Training loss: 14m 5s (- 85m 9s) (14200 14%) 3.8508
# Validation loss: 14m 9s (- 85m 35s) (14200 14%) 3.1160
# ##########################################################
# Training loss: 14m 11s (- 85m 2s) (14300 14%) 3.8733
# Validation loss: 14m 15s (- 85m 28s) (14300 14%) 3.1161
# ##########################################################
# Training loss: 14m 17s (- 84m 56s) (14400 14%) 4.1389
# Validation loss: 14m 21s (- 85m 21s) (14400 14%) 3.2112
# ##########################################################
# Training loss: 14m 23s (- 84m 49s) (14500 14%) 3.9952
# Validation loss: 14m 27s (- 85m 15s) (14500 14%) 3.3204
# ##########################################################
# Training loss: 14m 29s (- 84m 43s) (14600 14%) 4.0202
# Validation loss: 14m 33s (- 85m 8s) (14600 14%) 3.1154
# ##########################################################
# Training loss: 14m 34s (- 84m 36s) (14700 14%) 3.8818
# Validation loss: 14m 39s (- 85m 1s) (14700 14%) 3.1089
# ##########################################################
# Training loss: 14m 40s (- 84m 29s) (14800 14%) 3.6859
# Validation loss: 14m 44s (- 84m 53s) (14800 14%) 3.1124
# ##########################################################
# Training loss: 14m 46s (- 84m 22s) (14900 14%) 3.8518
# Validation loss: 14m 50s (- 84m 46s) (14900 14%) 3.1105
# ##########################################################
# Training loss: 14m 52s (- 84m 16s) (15000 15%) 3.9441
# Validation loss: 14m 56s (- 84m 42s) (15000 15%) 3.6218
# ##########################################################
# Training loss: 14m 58s (- 84m 11s) (15100 15%) 3.7802
# Validation loss: 15m 2s (- 84m 36s) (15100 15%) 3.1112
# ##########################################################
# Training loss: 15m 4s (- 84m 5s) (15200 15%) 4.0730
# Validation loss: 15m 9s (- 84m 31s) (15200 15%) 3.5615
# ##########################################################
# Training loss: 15m 10s (- 84m 0s) (15300 15%) 3.8290
# Validation loss: 15m 14s (- 84m 25s) (15300 15%) 3.2414
# ##########################################################
# Training loss: 15m 16s (- 83m 54s) (15400 15%) 4.0359
# Validation loss: 15m 20s (- 84m 18s) (15400 15%) 3.1445
# ##########################################################
# Training loss: 15m 22s (- 83m 48s) (15500 15%) 3.9717
# Validation loss: 15m 27s (- 84m 14s) (15500 15%) 3.6698
# ##########################################################
# Training loss: 15m 28s (- 83m 44s) (15600 15%) 3.9983
# Validation loss: 15m 33s (- 84m 8s) (15600 15%) 3.1033
# ##########################################################
# Training loss: 15m 34s (- 83m 38s) (15700 15%) 3.7530
# Validation loss: 15m 38s (- 84m 1s) (15700 15%) 3.1061
# ##########################################################
# Training loss: 15m 40s (- 83m 32s) (15800 15%) 4.0442
# Validation loss: 15m 45s (- 83m 56s) (15800 15%) 3.4481
# ##########################################################
# Training loss: 15m 46s (- 83m 27s) (15900 15%) 4.1588
# Validation loss: 15m 51s (- 83m 53s) (15900 15%) 3.7750
# ##########################################################
# Training loss: 15m 53s (- 83m 23s) (16000 16%) 3.9015
# Validation loss: 15m 57s (- 83m 48s) (16000 16%) 3.7730
# ##########################################################
# Training loss: 15m 59s (- 83m 19s) (16100 16%) 4.0077
# Validation loss: 16m 4s (- 83m 44s) (16100 16%) 3.6725
# ##########################################################
# Training loss: 16m 5s (- 83m 15s) (16200 16%) 3.7838
# Validation loss: 16m 10s (- 83m 38s) (16200 16%) 3.3865
# ##########################################################
# Training loss: 16m 11s (- 83m 9s) (16300 16%) 3.9866
# Validation loss: 16m 16s (- 83m 34s) (16300 16%) 3.7495
# ##########################################################
# Training loss: 16m 18s (- 83m 6s) (16400 16%) 3.9590
# Validation loss: 16m 22s (- 83m 30s) (16400 16%) 3.6024
# ##########################################################
# Training loss: 16m 24s (- 83m 1s) (16500 16%) 4.1044
# Validation loss: 16m 28s (- 83m 24s) (16500 16%) 3.4438
# ##########################################################
# Training loss: 16m 30s (- 82m 56s) (16600 16%) 3.8213
# Validation loss: 16m 35s (- 83m 20s) (16600 16%) 3.7687
# ##########################################################
# Training loss: 16m 36s (- 82m 52s) (16700 16%) 3.9930
# Validation loss: 16m 41s (- 83m 16s) (16700 16%) 3.7302
# ##########################################################
# Training loss: 16m 43s (- 82m 48s) (16800 16%) 3.8931
# Validation loss: 16m 48s (- 83m 12s) (16800 16%) 3.5151
# ##########################################################
# Training loss: 16m 49s (- 82m 43s) (16900 16%) 3.7876
# Validation loss: 16m 53s (- 83m 5s) (16900 16%) 3.1574
# ##########################################################
# Training loss: 16m 55s (- 82m 38s) (17000 17%) 4.1370
# Validation loss: 17m 0s (- 83m 2s) (17000 17%) 3.7647
# ##########################################################
# Training loss: 17m 1s (- 82m 34s) (17100 17%) 3.9835
# Validation loss: 17m 6s (- 82m 57s) (17100 17%) 3.6210
# ##########################################################
# Training loss: 17m 8s (- 82m 30s) (17200 17%) 3.9179
# Validation loss: 17m 13s (- 82m 53s) (17200 17%) 3.7691
# ##########################################################
# Training loss: 17m 14s (- 82m 25s) (17300 17%) 3.9900
# Validation loss: 17m 19s (- 82m 48s) (17300 17%) 3.7584
# ##########################################################
# Training loss: 17m 20s (- 82m 21s) (17400 17%) 3.8672
# Validation loss: 17m 25s (- 82m 42s) (17400 17%) 3.3705
# ##########################################################
# Training loss: 17m 26s (- 82m 15s) (17500 17%) 3.9108
# Validation loss: 17m 31s (- 82m 37s) (17500 17%) 3.5096
# ##########################################################
# Training loss: 17m 33s (- 82m 10s) (17600 17%) 4.0892
# Validation loss: 17m 37s (- 82m 33s) (17600 17%) 3.6737
# ##########################################################
# Training loss: 17m 39s (- 82m 6s) (17700 17%) 3.9347
# Validation loss: 17m 43s (- 82m 26s) (17700 17%) 3.1107
# ##########################################################
# Training loss: 17m 45s (- 81m 59s) (17800 17%) 3.7738
# Validation loss: 17m 49s (- 82m 20s) (17800 17%) 3.1204
# ##########################################################
# Training loss: 17m 51s (- 81m 53s) (17900 17%) 3.7212
# Validation loss: 17m 55s (- 82m 13s) (17900 17%) 3.0887
# ##########################################################
# Training loss: 17m 57s (- 81m 46s) (18000 18%) 3.8472
# Validation loss: 18m 1s (- 82m 7s) (18000 18%) 3.4617
# ##########################################################
# Training loss: 18m 3s (- 81m 40s) (18100 18%) 3.8126
# Validation loss: 18m 7s (- 82m 1s) (18100 18%) 3.4642
# ##########################################################
# Training loss: 18m 9s (- 81m 35s) (18200 18%) 3.9404
# Validation loss: 18m 13s (- 81m 56s) (18200 18%) 3.5108
# ##########################################################
# Training loss: 18m 15s (- 81m 30s) (18300 18%) 3.7979
# Validation loss: 18m 19s (- 81m 50s) (18300 18%) 3.3030
# ##########################################################
# Training loss: 18m 21s (- 81m 24s) (18400 18%) 3.8661
# Validation loss: 18m 25s (- 81m 44s) (18400 18%) 3.5875
# ##########################################################
# Training loss: 18m 27s (- 81m 19s) (18500 18%) 3.9291
# Validation loss: 18m 32s (- 81m 39s) (18500 18%) 3.7281
# ##########################################################
# Training loss: 18m 33s (- 81m 13s) (18600 18%) 3.8142
# Validation loss: 18m 38s (- 81m 33s) (18600 18%) 3.1650
# ##########################################################
# Training loss: 18m 39s (- 81m 8s) (18700 18%) 4.0210
# Validation loss: 18m 44s (- 81m 27s) (18700 18%) 3.2515
# ##########################################################
# Training loss: 18m 45s (- 81m 2s) (18800 18%) 3.7135
# Validation loss: 18m 50s (- 81m 20s) (18800 18%) 3.0710
# ##########################################################
# Training loss: 18m 51s (- 80m 55s) (18900 18%) 3.9775
# Validation loss: 18m 56s (- 81m 16s) (18900 18%) 3.7014
# ##########################################################
# Training loss: 18m 58s (- 80m 51s) (19000 19%) 4.1202
# Validation loss: 19m 2s (- 81m 12s) (19000 19%) 3.7118
# ##########################################################
# Training loss: 19m 4s (- 80m 47s) (19100 19%) 3.7532
# Validation loss: 19m 9s (- 81m 7s) (19100 19%) 3.5783
# ##########################################################
# Training loss: 19m 10s (- 80m 42s) (19200 19%) 4.0187
# Validation loss: 19m 15s (- 81m 1s) (19200 19%) 3.3150
# ##########################################################
# Training loss: 19m 16s (- 80m 37s) (19300 19%) 3.8117
# Validation loss: 19m 21s (- 80m 56s) (19300 19%) 3.5577
# ##########################################################
# Training loss: 19m 22s (- 80m 31s) (19400 19%) 3.7085
# Validation loss: 19m 27s (- 80m 49s) (19400 19%) 3.0682
# ##########################################################
# Training loss: 19m 28s (- 80m 24s) (19500 19%) 3.8624
# Validation loss: 19m 33s (- 80m 44s) (19500 19%) 3.6967
# ##########################################################
# Training loss: 19m 35s (- 80m 20s) (19600 19%) 4.0164
# Validation loss: 19m 39s (- 80m 39s) (19600 19%) 3.5699
# ##########################################################
# Training loss: 19m 41s (- 80m 14s) (19700 19%) 4.0551
# Validation loss: 19m 45s (- 80m 32s) (19700 19%) 3.1536
# ##########################################################
# Training loss: 19m 47s (- 80m 8s) (19800 19%) 3.9483
# Validation loss: 19m 52s (- 80m 28s) (19800 19%) 3.7518
# ##########################################################
# Training loss: 19m 53s (- 80m 4s) (19900 19%) 4.0345
# Validation loss: 19m 58s (- 80m 24s) (19900 19%) 3.7495
# ##########################################################
# Training loss: 20m 0s (- 80m 0s) (20000 20%) 3.9694
# Validation loss: 20m 4s (- 80m 19s) (20000 20%) 3.7409
# ##########################################################
# Training loss: 20m 6s (- 79m 55s) (20100 20%) 3.7914
# Validation loss: 20m 11s (- 80m 14s) (20100 20%) 3.7294
# ##########################################################
# Training loss: 20m 12s (- 79m 50s) (20200 20%) 3.9021
# Validation loss: 20m 17s (- 80m 9s) (20200 20%) 3.6259
# ##########################################################
# Training loss: 20m 19s (- 79m 46s) (20300 20%) 4.0225
# Validation loss: 20m 23s (- 80m 5s) (20300 20%) 3.7407
# ##########################################################
# Training loss: 20m 25s (- 79m 41s) (20400 20%) 4.0044
# Validation loss: 20m 30s (- 80m 0s) (20400 20%) 3.6481
# ##########################################################
# Training loss: 20m 31s (- 79m 37s) (20500 20%) 4.1591
# Validation loss: 20m 36s (- 79m 55s) (20500 20%) 3.7370
# ##########################################################
# Training loss: 20m 38s (- 79m 32s) (20600 20%) 4.0967
# Validation loss: 20m 43s (- 79m 50s) (20600 20%) 3.6861
# ##########################################################
# Training loss: 20m 44s (- 79m 27s) (20700 20%) 3.9645
# Validation loss: 20m 49s (- 79m 46s) (20700 20%) 3.6771
# ##########################################################
# Training loss: 20m 50s (- 79m 23s) (20800 20%) 3.9237
# Validation loss: 20m 55s (- 79m 39s) (20800 20%) 3.0572
# ##########################################################
# Training loss: 20m 56s (- 79m 16s) (20900 20%) 3.7967
# Validation loss: 21m 1s (- 79m 32s) (20900 20%) 3.0561
# ##########################################################
# Training loss: 21m 2s (- 79m 9s) (21000 21%) 3.7073
# Validation loss: 21m 6s (- 79m 25s) (21000 21%) 3.0547
# ##########################################################
# Training loss: 21m 8s (- 79m 2s) (21100 21%) 3.8074
# Validation loss: 21m 13s (- 79m 20s) (21100 21%) 3.5309
# ##########################################################
# Training loss: 21m 14s (- 78m 57s) (21200 21%) 3.7537
# Validation loss: 21m 18s (- 79m 13s) (21200 21%) 3.0508
# ##########################################################
# Training loss: 21m 20s (- 78m 50s) (21300 21%) 3.7002
# Validation loss: 21m 25s (- 79m 8s) (21300 21%) 3.5858
# ##########################################################
# Training loss: 21m 26s (- 78m 45s) (21400 21%) 4.0430
# Validation loss: 21m 31s (- 79m 3s) (21400 21%) 3.7318
# ##########################################################
# Training loss: 21m 32s (- 78m 40s) (21500 21%) 4.1033
# Validation loss: 21m 37s (- 78m 58s) (21500 21%) 3.6826
# ##########################################################
# Training loss: 21m 39s (- 78m 36s) (21600 21%) 3.8476
# Validation loss: 21m 44s (- 78m 53s) (21600 21%) 3.4734
# ##########################################################
# Training loss: 21m 45s (- 78m 30s) (21700 21%) 3.5905
# Validation loss: 21m 49s (- 78m 46s) (21700 21%) 3.2732
# ##########################################################
# Training loss: 21m 51s (- 78m 24s) (21800 21%) 3.7775
# Validation loss: 21m 55s (- 78m 40s) (21800 21%) 3.2142
# ##########################################################
# Training loss: 21m 57s (- 78m 18s) (21900 21%) 3.9714
# Validation loss: 22m 2s (- 78m 34s) (21900 21%) 3.2229
# ##########################################################
# Training loss: 22m 3s (- 78m 13s) (22000 22%) 3.9621
# Validation loss: 22m 8s (- 78m 30s) (22000 22%) 3.7301
# ##########################################################
# Training loss: 22m 10s (- 78m 8s) (22100 22%) 4.0432
# Validation loss: 22m 14s (- 78m 25s) (22100 22%) 3.7217
# ##########################################################
# Training loss: 22m 16s (- 78m 3s) (22200 22%) 3.7315
# Validation loss: 22m 20s (- 78m 19s) (22200 22%) 3.2970
# ##########################################################
# Training loss: 22m 22s (- 77m 57s) (22300 22%) 3.9131
# Validation loss: 22m 27s (- 78m 14s) (22300 22%) 3.6137
# ##########################################################
# Training loss: 22m 28s (- 77m 52s) (22400 22%) 3.8928
# Validation loss: 22m 33s (- 78m 7s) (22400 22%) 3.0503
# ##########################################################
# Training loss: 22m 34s (- 77m 45s) (22500 22%) 3.8282
# Validation loss: 22m 39s (- 78m 1s) (22500 22%) 3.3502
# ##########################################################
# Training loss: 22m 40s (- 77m 39s) (22600 22%) 3.8356
# Validation loss: 22m 45s (- 77m 55s) (22600 22%) 3.4401
# ##########################################################
# Training loss: 22m 46s (- 77m 34s) (22700 22%) 3.9320
# Validation loss: 22m 51s (- 77m 48s) (22700 22%) 3.0546
# ##########################################################
# Training loss: 22m 52s (- 77m 27s) (22800 22%) 3.6912
# Validation loss: 22m 56s (- 77m 41s) (22800 22%) 3.0506
# ##########################################################
# Training loss: 22m 58s (- 77m 20s) (22900 22%) 3.7798
# Validation loss: 23m 2s (- 77m 35s) (22900 22%) 3.0553
# ##########################################################
# Training loss: 23m 4s (- 77m 13s) (23000 23%) 3.5261
# Validation loss: 23m 8s (- 77m 28s) (23000 23%) 3.0446
# ##########################################################
# Training loss: 23m 9s (- 77m 7s) (23100 23%) 3.8976
# Validation loss: 23m 14s (- 77m 21s) (23100 23%) 3.0460
# ##########################################################
# Training loss: 23m 15s (- 77m 0s) (23200 23%) 3.6350
# Validation loss: 23m 20s (- 77m 16s) (23200 23%) 3.6494
# ##########################################################
# Training loss: 23m 21s (- 76m 54s) (23300 23%) 3.7815
# Validation loss: 23m 26s (- 77m 9s) (23300 23%) 3.2916
# ##########################################################
# Training loss: 23m 27s (- 76m 49s) (23400 23%) 3.6346
# Validation loss: 23m 32s (- 77m 4s) (23400 23%) 3.4887
# ##########################################################
# Training loss: 23m 34s (- 76m 44s) (23500 23%) 4.0048
# Validation loss: 23m 38s (- 76m 58s) (23500 23%) 3.5001
# ##########################################################
# Training loss: 23m 40s (- 76m 38s) (23600 23%) 3.8830
# Validation loss: 23m 44s (- 76m 52s) (23600 23%) 3.0629
# ##########################################################
# Training loss: 23m 46s (- 76m 31s) (23700 23%) 3.6258
# Validation loss: 23m 50s (- 76m 45s) (23700 23%) 3.0567
# ##########################################################
# Training loss: 23m 52s (- 76m 25s) (23800 23%) 3.8237
# Validation loss: 23m 56s (- 76m 39s) (23800 23%) 3.1348
# ##########################################################
# Training loss: 23m 57s (- 76m 18s) (23900 23%) 3.8121
# Validation loss: 24m 2s (- 76m 32s) (23900 23%) 3.0420
# ##########################################################
# Training loss: 24m 3s (- 76m 11s) (24000 24%) 3.5607
# Validation loss: 24m 8s (- 76m 25s) (24000 24%) 3.0387
# ##########################################################
# Training loss: 24m 9s (- 76m 5s) (24100 24%) 3.6894
# Validation loss: 24m 14s (- 76m 20s) (24100 24%) 3.5863
# ##########################################################
# Training loss: 24m 15s (- 76m 0s) (24200 24%) 3.9589
# Validation loss: 24m 20s (- 76m 14s) (24200 24%) 3.0698
# ##########################################################
# Training loss: 24m 21s (- 75m 54s) (24300 24%) 3.6803
# Validation loss: 24m 26s (- 76m 8s) (24300 24%) 3.7144
# ##########################################################
# Training loss: 24m 28s (- 75m 49s) (24400 24%) 3.9651
# Validation loss: 24m 32s (- 76m 3s) (24400 24%) 3.7193
# ##########################################################
# Training loss: 24m 34s (- 75m 43s) (24500 24%) 3.7497
# Validation loss: 24m 38s (- 75m 56s) (24500 24%) 3.0382
# ##########################################################
# Training loss: 24m 40s (- 75m 37s) (24600 24%) 3.7149
# Validation loss: 24m 45s (- 75m 51s) (24600 24%) 3.7163
# ##########################################################
# Training loss: 24m 46s (- 75m 32s) (24700 24%) 4.0646
# Validation loss: 24m 51s (- 75m 47s) (24700 24%) 3.6607
# ##########################################################
# Training loss: 24m 53s (- 75m 27s) (24800 24%) 3.9196
# Validation loss: 24m 57s (- 75m 42s) (24800 24%) 3.6962
# ##########################################################
# Training loss: 24m 59s (- 75m 22s) (24900 24%) 3.8241
# Validation loss: 25m 4s (- 75m 37s) (24900 24%) 3.7251
# ##########################################################
# Training loss: 25m 5s (- 75m 17s) (25000 25%) 3.8789
# Validation loss: 25m 10s (- 75m 32s) (25000 25%) 3.7294
# ##########################################################
# Training loss: 25m 12s (- 75m 12s) (25100 25%) 3.9386
# Validation loss: 25m 17s (- 75m 27s) (25100 25%) 3.7223
# ##########################################################
# Training loss: 25m 18s (- 75m 8s) (25200 25%) 4.0708
# Validation loss: 25m 23s (- 75m 22s) (25200 25%) 3.7158
# ##########################################################
# Training loss: 25m 25s (- 75m 2s) (25300 25%) 3.8633
# Validation loss: 25m 29s (- 75m 15s) (25300 25%) 3.0743
# ##########################################################
# Training loss: 25m 30s (- 74m 56s) (25400 25%) 3.8553
# Validation loss: 25m 35s (- 75m 9s) (25400 25%) 3.1737
# ##########################################################
# Training loss: 25m 36s (- 74m 49s) (25500 25%) 3.5724
# Validation loss: 25m 41s (- 75m 2s) (25500 25%) 3.0320
# ##########################################################
# Training loss: 25m 42s (- 74m 43s) (25600 25%) 3.8495
# Validation loss: 25m 47s (- 74m 56s) (25600 25%) 3.0323
# ##########################################################
# Training loss: 25m 48s (- 74m 36s) (25700 25%) 3.5344
# Validation loss: 25m 52s (- 74m 49s) (25700 25%) 3.0342
# ##########################################################
# Training loss: 25m 54s (- 74m 30s) (25800 25%) 3.7222
# Validation loss: 25m 58s (- 74m 43s) (25800 25%) 3.1202
# ##########################################################
# Training loss: 26m 0s (- 74m 24s) (25900 25%) 3.6234
# Validation loss: 26m 4s (- 74m 36s) (25900 25%) 3.0997
# ##########################################################
# Training loss: 26m 6s (- 74m 17s) (26000 26%) 3.8422
# Validation loss: 26m 10s (- 74m 30s) (26000 26%) 3.0412
# ##########################################################
# Training loss: 26m 12s (- 74m 11s) (26100 26%) 3.5389
# Validation loss: 26m 16s (- 74m 24s) (26100 26%) 3.4510
# ##########################################################
# Training loss: 26m 18s (- 74m 5s) (26200 26%) 3.7843
# Validation loss: 26m 23s (- 74m 19s) (26200 26%) 3.6265
# ##########################################################
# Training loss: 26m 24s (- 74m 0s) (26300 26%) 3.9561
# Validation loss: 26m 29s (- 74m 13s) (26300 26%) 3.6718
# ##########################################################
# Training loss: 26m 30s (- 73m 55s) (26400 26%) 4.2214
# Validation loss: 26m 36s (- 74m 9s) (26400 26%) 4.1627
# ##########################################################
# Training loss: 26m 37s (- 73m 51s) (26500 26%) 4.2281
# Validation loss: 26m 42s (- 74m 5s) (26500 26%) 4.1489
# ##########################################################
# Training loss: 26m 44s (- 73m 47s) (26600 26%) 4.2341
# Validation loss: 26m 49s (- 74m 2s) (26600 26%) 4.1520
# ##########################################################
# Training loss: 26m 51s (- 73m 44s) (26700 26%) 4.2063
# Validation loss: 26m 56s (- 73m 58s) (26700 26%) 4.1513
# ##########################################################
# Training loss: 26m 58s (- 73m 40s) (26800 26%) 4.2038
# Validation loss: 27m 3s (- 73m 53s) (26800 26%) 3.9110
# ##########################################################
# Training loss: 27m 4s (- 73m 35s) (26900 26%) 4.1426
# Validation loss: 27m 10s (- 73m 49s) (26900 26%) 4.1444
# ##########################################################
# Training loss: 27m 11s (- 73m 32s) (27000 27%) 4.1304
# Validation loss: 27m 17s (- 73m 46s) (27000 27%) 4.1475
# ##########################################################
# Training loss: 27m 18s (- 73m 28s) (27100 27%) 4.0027
# Validation loss: 27m 23s (- 73m 41s) (27100 27%) 4.0029
# ##########################################################
# Training loss: 27m 25s (- 73m 23s) (27200 27%) 4.0456
# Validation loss: 27m 30s (- 73m 37s) (27200 27%) 4.1315
# ##########################################################
# Training loss: 27m 32s (- 73m 19s) (27300 27%) 4.1943
# Validation loss: 27m 37s (- 73m 32s) (27300 27%) 4.0059
# ##########################################################
# Training loss: 27m 38s (- 73m 14s) (27400 27%) 4.0328
# Validation loss: 27m 43s (- 73m 28s) (27400 27%) 4.0382
# ##########################################################
# Training loss: 27m 45s (- 73m 10s) (27500 27%) 4.2153
# Validation loss: 27m 50s (- 73m 23s) (27500 27%) 3.7313
# ##########################################################
# Training loss: 27m 52s (- 73m 6s) (27600 27%) 4.0058
# Validation loss: 27m 57s (- 73m 19s) (27600 27%) 4.1183
# ##########################################################
# Training loss: 27m 58s (- 73m 2s) (27700 27%) 4.2527
# Validation loss: 28m 4s (- 73m 15s) (27700 27%) 4.1146
# ##########################################################
# Training loss: 28m 5s (- 72m 58s) (27800 27%) 4.1806
# Validation loss: 28m 10s (- 73m 11s) (27800 27%) 3.8369
# ##########################################################
# Training loss: 28m 12s (- 72m 53s) (27900 27%) 3.9507
# Validation loss: 28m 17s (- 73m 5s) (27900 27%) 3.6502
# ##########################################################
# Training loss: 28m 18s (- 72m 48s) (28000 28%) 4.0424
# Validation loss: 28m 24s (- 73m 1s) (28000 28%) 4.1176
# ##########################################################
# Training loss: 28m 25s (- 72m 44s) (28100 28%) 4.0696
# Validation loss: 28m 30s (- 72m 57s) (28100 28%) 4.1006
# ##########################################################
# Training loss: 28m 32s (- 72m 40s) (28200 28%) 4.0180
# Validation loss: 28m 37s (- 72m 52s) (28200 28%) 3.6490
# ##########################################################
# Training loss: 28m 38s (- 72m 35s) (28300 28%) 4.0493
# Validation loss: 28m 44s (- 72m 48s) (28300 28%) 4.1224
# ##########################################################
# Training loss: 28m 45s (- 72m 31s) (28400 28%) 4.1412
# Validation loss: 28m 50s (- 72m 44s) (28400 28%) 4.1056
# ##########################################################
# Training loss: 28m 52s (- 72m 26s) (28500 28%) 4.0610
# Validation loss: 28m 57s (- 72m 38s) (28500 28%) 3.6447
# ##########################################################
# Training loss: 28m 59s (- 72m 21s) (28600 28%) 3.9196
# Validation loss: 29m 4s (- 72m 34s) (28600 28%) 4.1118
# ##########################################################
# Training loss: 29m 5s (- 72m 17s) (28700 28%) 3.9605
# Validation loss: 29m 10s (- 72m 28s) (28700 28%) 3.6375
# ##########################################################
# Training loss: 29m 12s (- 72m 11s) (28800 28%) 3.9071
# Validation loss: 29m 17s (- 72m 24s) (28800 28%) 3.9569
# ##########################################################
# Training loss: 29m 18s (- 72m 7s) (28900 28%) 4.1124
# ...
# Validation loss: 46m 49s (- 57m 14s) (45000 45%) 3.9136
# ##########################################################
# Training loss: 46m 51s (- 57m 2s) (45100 45%) 3.8672
# Validation loss: 46m 56s (- 57m 8s) (45100 45%) 3.8978
# ##########################################################
# Training loss: 46m 58s (- 56m 56s) (45200 45%) 3.8602
# Validation loss: 47m 3s (- 57m 3s) (45200 45%) 3.7120
# ##########################################################
# Training loss: 47m 4s (- 56m 51s) (45300 45%) 3.7933
# Validation loss: 47m 10s (- 56m 57s) (45300 45%) 3.8245
# ##########################################################
# Training loss: 47m 11s (- 56m 45s) (45400 45%) 3.7987
# Validation loss: 47m 16s (- 56m 51s) (45400 45%) 3.7996
# ##########################################################
# Training loss: 47m 18s (- 56m 39s) (45500 45%) 3.9774
# Validation loss: 47m 23s (- 56m 46s) (45500 45%) 3.8540
# ##########################################################
# Training loss: 47m 25s (- 56m 34s) (45600 45%) 4.1123
# Validation loss: 47m 30s (- 56m 40s) (45600 45%) 3.8147
# ##########################################################
# Training loss: 47m 32s (- 56m 28s) (45700 45%) 4.0961
# Validation loss: 47m 37s (- 56m 35s) (45700 45%) 3.7760
# ##########################################################
# Training loss: 47m 38s (- 56m 23s) (45800 45%) 4.0392
# Validation loss: 47m 44s (- 56m 29s) (45800 45%) 3.9382
# ##########################################################
# Training loss: 47m 45s (- 56m 17s) (45900 45%) 4.0487
# Validation loss: 47m 51s (- 56m 24s) (45900 45%) 4.0076
# ##########################################################
# Training loss: 47m 52s (- 56m 12s) (46000 46%) 4.2171
# Validation loss: 47m 58s (- 56m 18s) (46000 46%) 3.9864
# ##########################################################
# Training loss: 47m 59s (- 56m 7s) (46100 46%) 4.1016
# Validation loss: 48m 5s (- 56m 13s) (46100 46%) 3.9487
# ##########################################################
# Training loss: 48m 6s (- 56m 1s) (46200 46%) 4.0823
# Validation loss: 48m 12s (- 56m 7s) (46200 46%) 4.0461
# ##########################################################
# Training loss: 48m 13s (- 55m 56s) (46300 46%) 4.1162
# Validation loss: 48m 18s (- 56m 2s) (46300 46%) 3.7983
# ##########################################################
# Training loss: 48m 20s (- 55m 50s) (46400 46%) 3.8830
# Validation loss: 48m 25s (- 55m 56s) (46400 46%) 3.8413
# ##########################################################
# Training loss: 48m 27s (- 55m 44s) (46500 46%) 3.9210
# Validation loss: 48m 32s (- 55m 50s) (46500 46%) 3.7969
# ##########################################################
# Training loss: 48m 33s (- 55m 38s) (46600 46%) 3.7269
# Validation loss: 48m 38s (- 55m 44s) (46600 46%) 3.7663
# ##########################################################
# Training loss: 48m 40s (- 55m 33s) (46700 46%) 4.0355
# Validation loss: 48m 45s (- 55m 38s) (46700 46%) 3.7262
# ##########################################################
# Training loss: 48m 46s (- 55m 27s) (46800 46%) 4.0573
# Validation loss: 48m 51s (- 55m 32s) (46800 46%) 3.6068
# ##########################################################
# Training loss: 48m 53s (- 55m 21s) (46900 46%) 4.1144
# Validation loss: 48m 58s (- 55m 27s) (46900 46%) 3.8013
# ##########################################################
# Training loss: 49m 0s (- 55m 15s) (47000 47%) 4.0272
# Validation loss: 49m 5s (- 55m 21s) (47000 47%) 4.0125
# ##########################################################
# Training loss: 49m 7s (- 55m 10s) (47100 47%) 4.1824
# Validation loss: 49m 12s (- 55m 16s) (47100 47%) 3.9702
# ##########################################################
# Training loss: 49m 14s (- 55m 4s) (47200 47%) 4.0632
# Validation loss: 49m 19s (- 55m 11s) (47200 47%) 4.2801
# ##########################################################
# Training loss: 49m 21s (- 54m 59s) (47300 47%) 4.0999
# Validation loss: 49m 27s (- 55m 5s) (47300 47%) 4.0261
# ##########################################################
# Training loss: 49m 28s (- 54m 54s) (47400 47%) 4.2124
# Validation loss: 49m 34s (- 55m 0s) (47400 47%) 4.0526
# ##########################################################
# Training loss: 49m 35s (- 54m 48s) (47500 47%) 3.9207
# Validation loss: 49m 40s (- 54m 54s) (47500 47%) 3.7150
# ##########################################################
# Training loss: 49m 42s (- 54m 43s) (47600 47%) 4.0396
# Validation loss: 49m 47s (- 54m 49s) (47600 47%) 3.9376
# ##########################################################
# Training loss: 49m 49s (- 54m 37s) (47700 47%) 3.9544
# Validation loss: 49m 54s (- 54m 43s) (47700 47%) 3.9598
# ##########################################################
# Training loss: 49m 56s (- 54m 32s) (47800 47%) 3.9448
# Validation loss: 50m 1s (- 54m 38s) (47800 47%) 3.9827
# ##########################################################
# Training loss: 50m 3s (- 54m 26s) (47900 47%) 3.8108
# Validation loss: 50m 8s (- 54m 32s) (47900 47%) 4.0009
# ##########################################################
# Training loss: 50m 10s (- 54m 21s) (48000 48%) 3.9702
# Validation loss: 50m 15s (- 54m 27s) (48000 48%) 4.0405
# ##########################################################
# Training loss: 50m 17s (- 54m 15s) (48100 48%) 4.1182
# Validation loss: 50m 22s (- 54m 21s) (48100 48%) 3.8204
# ##########################################################
# Training loss: 50m 24s (- 54m 10s) (48200 48%) 3.8808
# Validation loss: 50m 29s (- 54m 15s) (48200 48%) 3.6126
# ##########################################################
# Training loss: 50m 30s (- 54m 4s) (48300 48%) 4.0056
# Validation loss: 50m 36s (- 54m 9s) (48300 48%) 4.0117
# ##########################################################
# Training loss: 50m 37s (- 53m 58s) (48400 48%) 4.1727
# Validation loss: 50m 42s (- 54m 3s) (48400 48%) 3.7641
# ##########################################################
# Training loss: 50m 44s (- 53m 52s) (48500 48%) 3.9193
# Validation loss: 50m 49s (- 53m 58s) (48500 48%) 3.8974
# ##########################################################
# Training loss: 50m 51s (- 53m 47s) (48600 48%) 3.8710
# Validation loss: 50m 56s (- 53m 52s) (48600 48%) 3.9993
# ##########################################################
# Training loss: 50m 58s (- 53m 41s) (48700 48%) 4.0003
# Validation loss: 51m 3s (- 53m 47s) (48700 48%) 4.0223
# ##########################################################
# Training loss: 51m 5s (- 53m 35s) (48800 48%) 3.9407
# Validation loss: 51m 10s (- 53m 41s) (48800 48%) 3.9895
# ##########################################################
# Training loss: 51m 11s (- 53m 30s) (48900 48%) 4.0864
# Validation loss: 51m 17s (- 53m 35s) (48900 48%) 4.0691
# ##########################################################
# Training loss: 51m 18s (- 53m 24s) (49000 49%) 4.1339
# Validation loss: 51m 24s (- 53m 30s) (49000 49%) 4.0487
# ##########################################################
# Training loss: 51m 25s (- 53m 19s) (49100 49%) 3.9708
# Validation loss: 51m 31s (- 53m 24s) (49100 49%) 4.1050
# ##########################################################
# Training loss: 51m 32s (- 53m 13s) (49200 49%) 4.1669
# Validation loss: 51m 38s (- 53m 19s) (49200 49%) 4.1520
# ##########################################################
# Training loss: 51m 40s (- 53m 8s) (49300 49%) 3.9883
# Validation loss: 51m 45s (- 53m 13s) (49300 49%) 3.7943
# ##########################################################
# Training loss: 51m 46s (- 53m 2s) (49400 49%) 3.9382
# Validation loss: 51m 52s (- 53m 7s) (49400 49%) 3.9548
# ##########################################################
# Training loss: 51m 53s (- 52m 56s) (49500 49%) 4.1285
# Validation loss: 51m 59s (- 53m 2s) (49500 49%) 3.9926
# ##########################################################
# Training loss: 52m 0s (- 52m 51s) (49600 49%) 4.1007
# Validation loss: 52m 6s (- 52m 56s) (49600 49%) 4.1147
# ##########################################################
# Training loss: 52m 8s (- 52m 45s) (49700 49%) 4.1216
# Validation loss: 52m 13s (- 52m 51s) (49700 49%) 4.1044
# ##########################################################
# Training loss: 52m 15s (- 52m 40s) (49800 49%) 4.1178
# Validation loss: 52m 20s (- 52m 45s) (49800 49%) 4.0343
# ##########################################################
# Training loss: 52m 22s (- 52m 34s) (49900 49%) 4.0230
# Validation loss: 52m 27s (- 52m 40s) (49900 49%) 4.0884
# ##########################################################
# Training loss: 52m 29s (- 52m 29s) (50000 50%) 3.8823
# Validation loss: 52m 34s (- 52m 34s) (50000 50%) 4.0029
# ##########################################################
# Training loss: 52m 35s (- 52m 23s) (50100 50%) 4.0799
# Validation loss: 52m 41s (- 52m 28s) (50100 50%) 3.8032
# ##########################################################
# Training loss: 52m 42s (- 52m 17s) (50200 50%) 3.9136
# Validation loss: 52m 47s (- 52m 22s) (50200 50%) 3.8019
# ##########################################################
# Training loss: 52m 49s (- 52m 11s) (50300 50%) 4.1521
# Validation loss: 52m 55s (- 52m 17s) (50300 50%) 4.1209
# ##########################################################
# Training loss: 52m 56s (- 52m 6s) (50400 50%) 4.0856
# Validation loss: 53m 1s (- 52m 11s) (50400 50%) 3.8946
# ##########################################################
# Training loss: 53m 3s (- 52m 0s) (50500 50%) 4.0224
# Validation loss: 53m 8s (- 52m 5s) (50500 50%) 3.7855
# ##########################################################
# Training loss: 53m 10s (- 51m 54s) (50600 50%) 3.8512
# Validation loss: 53m 15s (- 51m 59s) (50600 50%) 3.8553
# ##########################################################
# Training loss: 53m 17s (- 51m 48s) (50700 50%) 4.0753
# Validation loss: 53m 22s (- 51m 53s) (50700 50%) 3.7183
# ##########################################################
# Training loss: 53m 23s (- 51m 42s) (50800 50%) 4.0561
# Validation loss: 53m 29s (- 51m 48s) (50800 50%) 3.9388
# ##########################################################
# Training loss: 53m 30s (- 51m 37s) (50900 50%) 3.9454
# Validation loss: 53m 36s (- 51m 42s) (50900 50%) 3.7835
# ##########################################################
# Training loss: 53m 37s (- 51m 31s) (51000 51%) 3.8459
# Validation loss: 53m 43s (- 51m 36s) (51000 51%) 4.0335
# ##########################################################
# Training loss: 53m 45s (- 51m 26s) (51100 51%) 3.9243
# Validation loss: 53m 51s (- 51m 32s) (51100 51%) 3.9821
# ##########################################################
# Training loss: 53m 52s (- 51m 21s) (51200 51%) 4.0253
# Validation loss: 53m 59s (- 51m 27s) (51200 51%) 4.0300
# ##########################################################
# Training loss: 54m 1s (- 51m 16s) (51300 51%) 3.9557
# Validation loss: 54m 7s (- 51m 22s) (51300 51%) 3.8621
# ##########################################################
# Training loss: 54m 9s (- 51m 12s) (51400 51%) 4.0551
# Validation loss: 54m 15s (- 51m 18s) (51400 51%) 4.0667
# ##########################################################
# Training loss: 54m 17s (- 51m 7s) (51500 51%) 3.9738
# Validation loss: 54m 23s (- 51m 13s) (51500 51%) 3.9869
# ##########################################################
# Training loss: 54m 25s (- 51m 2s) (51600 51%) 3.9435
# Validation loss: 54m 30s (- 51m 8s) (51600 51%) 4.0536
# ##########################################################
# Training loss: 54m 32s (- 50m 57s) (51700 51%) 3.9760
# Validation loss: 54m 38s (- 51m 2s) (51700 51%) 4.1071
# ##########################################################
# Training loss: 54m 39s (- 50m 51s) (51800 51%) 3.9738
# Validation loss: 54m 45s (- 50m 56s) (51800 51%) 3.8248
# ##########################################################
# Training loss: 54m 46s (- 50m 46s) (51900 51%) 3.9600
# Validation loss: 54m 52s (- 50m 51s) (51900 51%) 3.7240
# ##########################################################
# Training loss: 54m 53s (- 50m 40s) (52000 52%) 4.0875
# Validation loss: 54m 58s (- 50m 45s) (52000 52%) 3.8016
# ##########################################################
# Training loss: 55m 0s (- 50m 34s) (52100 52%) 4.0498
# Validation loss: 55m 5s (- 50m 39s) (52100 52%) 3.8870
# ##########################################################
# Training loss: 55m 7s (- 50m 28s) (52200 52%) 4.0677
# Validation loss: 55m 13s (- 50m 33s) (52200 52%) 3.9742
# ##########################################################
# Training loss: 55m 14s (- 50m 23s) (52300 52%) 4.1197
# Validation loss: 55m 20s (- 50m 28s) (52300 52%) 3.9405
# ##########################################################
# Training loss: 55m 22s (- 50m 17s) (52400 52%) 3.8146
# Validation loss: 55m 27s (- 50m 23s) (52400 52%) 4.1696
# ##########################################################
# Training loss: 55m 29s (- 50m 12s) (52500 52%) 3.9791
# Validation loss: 55m 34s (- 50m 17s) (52500 52%) 3.8622
# ##########################################################
# Training loss: 55m 36s (- 50m 6s) (52600 52%) 3.9058
# Validation loss: 55m 41s (- 50m 11s) (52600 52%) 3.9067
# ##########################################################
# Training loss: 55m 43s (- 50m 0s) (52700 52%) 3.9393
# Validation loss: 55m 48s (- 50m 5s) (52700 52%) 3.9207
# ##########################################################
# Training loss: 55m 50s (- 49m 55s) (52800 52%) 4.1210
# Validation loss: 55m 56s (- 50m 0s) (52800 52%) 3.9427
# ##########################################################
# Training loss: 55m 57s (- 49m 49s) (52900 52%) 3.9184
# Validation loss: 56m 3s (- 49m 54s) (52900 52%) 3.8690
# ##########################################################
# Training loss: 56m 4s (- 49m 43s) (53000 53%) 3.9795
# Validation loss: 56m 10s (- 49m 48s) (53000 53%) 4.0238
# ##########################################################
# Training loss: 56m 11s (- 49m 38s) (53100 53%) 4.0308
# Validation loss: 56m 17s (- 49m 42s) (53100 53%) 3.8677
# ##########################################################
# Training loss: 56m 18s (- 49m 32s) (53200 53%) 3.8101
# Validation loss: 56m 24s (- 49m 37s) (53200 53%) 3.8746
# ##########################################################
# Training loss: 56m 25s (- 49m 26s) (53300 53%) 4.0560
# Validation loss: 56m 31s (- 49m 31s) (53300 53%) 3.9609
# ##########################################################
# Training loss: 56m 32s (- 49m 20s) (53400 53%) 4.0941
# Validation loss: 56m 38s (- 49m 25s) (53400 53%) 4.0660
# ##########################################################
# Training loss: 56m 40s (- 49m 15s) (53500 53%) 3.9110
# Validation loss: 56m 45s (- 49m 19s) (53500 53%) 3.8883
# ##########################################################
# Training loss: 56m 47s (- 49m 9s) (53600 53%) 3.9164
# Validation loss: 56m 52s (- 49m 13s) (53600 53%) 3.6432
# ##########################################################
# Training loss: 56m 53s (- 49m 3s) (53700 53%) 3.9364
# Validation loss: 56m 59s (- 49m 8s) (53700 53%) 3.9403
# ##########################################################
# Training loss: 57m 0s (- 48m 57s) (53800 53%) 3.8404
# Validation loss: 57m 7s (- 49m 2s) (53800 53%) 4.0493
# ##########################################################
# Training loss: 57m 8s (- 48m 52s) (53900 53%) 4.1569
# Validation loss: 57m 14s (- 48m 57s) (53900 53%) 4.1394
# ##########################################################
# Training loss: 57m 16s (- 48m 47s) (54000 54%) 4.0034
# Validation loss: 57m 21s (- 48m 51s) (54000 54%) 3.8925
# ##########################################################
# Training loss: 57m 23s (- 48m 41s) (54100 54%) 3.9137
# Validation loss: 57m 28s (- 48m 46s) (54100 54%) 4.0166
# ##########################################################
# Training loss: 57m 30s (- 48m 35s) (54200 54%) 3.9019
# Validation loss: 57m 36s (- 48m 40s) (54200 54%) 4.0685
# ##########################################################
# Training loss: 57m 38s (- 48m 30s) (54300 54%) 4.0180
# Validation loss: 57m 43s (- 48m 35s) (54300 54%) 3.9324
# ##########################################################
# Training loss: 57m 45s (- 48m 25s) (54400 54%) 3.9625
# Validation loss: 57m 51s (- 48m 29s) (54400 54%) 3.8188
# ##########################################################
# Training loss: 57m 52s (- 48m 19s) (54500 54%) 4.0462

# %% [markdown]
# ## Check some translations

# %%
# Load the best model 
#hidden_size = 1024
#encoder1 = EncoderRNN(len(english_vocab), hidden_size).to(device)
#attn_decoder1 = AttnDecoderRNN(hidden_size, len(indo_vocab), dropout_p=0.1).to(device)
#encoder1.load_state_dict(torch.load("./results/encoder-1800.pth"))
#encoder1.eval()

#attn_decoder1.load_state_dict(torch.load("./results/decoder-1800.pth"))
#attn_decoder1.eval()
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(4187, 1024)
#   (attn): Linear(in_features=2048, out_features=25, bias=True)
#   (attn_combine): Linear(in_features=2048, out_features=1024, bias=True)
#   (dropout): Dropout(p=0.1)
#   (gru): GRU(1024, 1024)
#   (out): Linear(in_features=1024, out_features=4187, bias=True)
# )

# %%
def translate(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))

translate("tom is playing with ball.")

translate("she is standing there .")

translate("he is a bad man .")

translate("he wants to sleep .")
# Out:
# input = tom is playing with ball.
# output = <s> tom tidak yang . . </s>
# input = she is standing there .
# output = <s> dia tidak . . </s>
# input = he is a bad man .
# output = <s> dia tidak yang . . </s>
# input = he wants to sleep .
# output = <s> dia tidak . . </s>
